# %% [markdown]
# # Import packages

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import requests
import seaborn as sns
import sys
import yaml

sys.path.insert(1, os.path.join(os.getcwd(), '../scripts'))
from parse_gro_files import read_residue_file, extract_info_from_gro
# Update font size for graphics
plt.rcParams.update({'font.size': 20})

# %% [markdown]
# # Load data

# %%
def clean_df(df, column_name='file_name'):
    remove = ['.DS_Store', '__MACOSX', '.git']
    df = df[~df[column_name].str.contains('|'.join(remove))].reset_index(drop=True)
    return df

# %%
def read_query_file(filename):
    """File query.yml parser.

    This function parses the query file.

    Parameters
    ----------
    filename : str
        Filename for query parameters.
    
    Returns
    -------
    file_types : dict
        Dictionary with type, engine, keywords to use and category
    """
    with open(filename, "r") as param_file:
        data_loaded = yaml.safe_load(param_file)
    file_types = data_loaded["file_types"]
    return file_types

# %%
def assign_file_category(file_type):
    """Assign file category based on file type.
    
    Parameters
    ----------
    file_type : str
        File extension.
    
    Returns
    -------
    str
        Category.
    """
    if file_type in list_coordinate:
        return "coordinate"
    elif file_type in list_topology:
        return "topology"
    elif file_type in list_trajectory:
        return "trajectory"
    else:
        return "none"

# %%
def assign_md_engine(file_type):
    """Assign MD engine based on file type.
    
    Parameters
    ----------
    file_type : str
        File extension.
    
    Returns
    -------
    str
        Name of MD engine.
    """
    if file_type in ext_gromacs:
        return "gromacs"
    elif file_type in ext_namd:
        return "namd"
    elif file_type in ext_amber:
        return "amber"
    else:
        return "none"

# %%
def extract_remote_info_from_gro(
    gro_file_path,
    target_path,
    gro_file_counter,
    gro_file_number,
    protein_residues,
    lipid_residues,
    nucleic_residues,
    water_ion_residues,
    glucid_residues
):
    """Extract information from Gromacs gro file.

    Parameters
    ----------
    gro_file_path : str
        Path to gro file
    target_path : str
        Path to the directory to find gro files
    gro_file_counter : int
        Counter for the current gro file
    gro_file_number : int
        Total number of gro files to parse
    protein_residues : list
        List of protein residues
    lipid_residues : list
        List of lipid residues
    nucleic_residues : lst
        List of nucleic acid residues
    water_ion_residues : lst
        List of water and ions
    glucid_residues : lst
        List of glucid residues

    Returns
    -------
    dict
        Dictionnary of extracted informations
    """
    AA_ref = {
        'ALA': 5,
        'ARG': 11,
        'ASN': 8,
        'ASP': 8,
        'CYS': 6,
        'GLN': 9,
        'GLU': 9,
        'GLY': 4,
        'HIS': 9,
        'HSD': 9,
        'ILE': 8,
        'LEU': 8,
        'LYS': 9,
        'MET': 8,
        'PHE': 11,
        'PRO': 7,
        'SER': 6,
        'THR': 7,
        'TRP': 14,
        'TYR': 12,
        'VAL': 7,
    }
    CG_list = ['BB', 'SC1', 'SC2', 'SC3']
    
    info = {
        "dataset_origin": None,
        "dataset_id": None,
        "atom_number": None,
        "has_protein": False,
        "has_nucleic": False,
        "has_lipid": False,
        "has_water_ion": False,
        "has_glucid": False,
        "filename": None,
        "is_AA": None,
    }
    info["dataset_origin"], info["dataset_id"], info["filename"] = str(
        target_path
    ).split("|")
    print(
        f"Reading {gro_file_counter:{len(str(gro_file_number))}d}/{gro_file_number} {str(gro_file_path)}"
    )
    f = requests.get(gro_file_path)
    prev_residue_number = -999
    all_gro = []
    for index, gro_file in enumerate(f):
        gro_file = gro_file.decode('UTF-8')
        all_gro.append(gro_file)
    gro_file = "".join(all_gro)
    for idx, line in enumerate(gro_file.split('\n')):
        if idx == 1:
            try:
                info["atom_number"] = int(line)
            except:
                pass
        if (idx > 1) and (len(line.rstrip()) <= 70) and (len(line.split()) > 3):
            residue_number = int(line[0:5])
            residue_name = line[5:10].strip()
            atom_name = line[10:15].strip()
            atom_number = int(line[15:20])
            if residue_name in AA_ref.keys():
                if prev_residue_number == -999:
                    prev_residue_number = residue_number
                    prev_residue_name = residue_name
                    num_atoms = 0
            if residue_name in protein_residues:
                info["has_protein"] = True
                if info["is_AA"] == None:
                    if atom_name in CG_list:
                        info["is_AA"] = False
                    else:
                        if prev_residue_number == residue_number:
                            num_atoms = num_atoms+1
                        else:
                            if prev_residue_name in AA_ref.keys():
                                if num_atoms > AA_ref[prev_residue_name]:
                                    info["is_AA"] = True
                                else:
                                    info["is_AA"] = False
                            else:
                                prev_residue_number = -999
            elif residue_name in lipid_residues:
                info["has_lipid"] = True
            elif residue_name in nucleic_residues:
                info["has_nucleic"] = True
            elif residue_name in water_ion_residues:
                info["has_water_ion"] = True
            elif residue_name in glucid_residues:
                info["has_glucid"] = True
            # WALL particles
            elif residue_name in ["WAL"]:
                pass
            else:
                pass
                #print(f"Unknown residue: {residue_name} / {str(gro_file_path)}")
    if info["is_AA"] == None:
        info["is_AA"] = False
    return info

# %%
def extract_remote_info_from_pdb(
    gro_file_path,
    target_path,
    gro_file_counter,
    gro_file_number,
    protein_residues,
    lipid_residues,
    nucleic_residues,
    water_ion_residues,
    glucid_residues
):
    """Extract information from pdb file.

    Parameters
    ----------
    gro_file_path : str
        Path to gro file
    target_path : str
        Path to the directory to find gro files
    gro_file_counter : int
        Counter for the current gro file
    gro_file_number : int
        Total number of gro files to parse
    protein_residues : list
        List of protein residues
    lipid_residues : list
        List of lipid residues
    nucleic_residues : lst
        List of nucleic acid residues
    water_ion_residues : lst
        List of water and ions
    glucid_residues : lst
        List of glucid residues

    Returns
    -------
    dict
        Dictionnary of extracted informations
    """
    AA_ref = {
        'ALA': 5,
        'ARG': 11,
        'ASN': 8,
        'ASP': 8,
        'CYS': 6,
        'GLN': 9,
        'GLU': 9,
        'GLY': 4,
        'HIS': 9,
        'HSD': 9,
        'ILE': 8,
        'LEU': 8,
        'LYS': 9,
        'MET': 8,
        'PHE': 11,
        'PRO': 7,
        'SER': 6,
        'THR': 7,
        'TRP': 14,
        'TYR': 12,
        'VAL': 7,
    }
    CG_list = ['BB', 'SC1', 'SC2', 'SC3']
    
    info = {
        "dataset_origin": None,
        "dataset_id": None,
        "atom_number": None,
        "has_protein": False,
        "has_nucleic": False,
        "has_lipid": False,
        "has_water_ion": False,
        "has_glucid": False,
        "filename": None,
        "is_AA": None,
    }
    info["dataset_origin"], info["dataset_id"], info["filename"] = str(
        target_path
    ).split("|")
    print(
        f"Reading {gro_file_counter:{len(str(gro_file_number))}d}/{gro_file_number} {str(gro_file_path)}"
    )
    f = requests.get(gro_file_path)
    prev_residue_number = -999
    atom_num = 0
    all_gro = []
    for index, gro_file in enumerate(f):
        gro_file = gro_file.decode('UTF-8')
        all_gro.append(gro_file)
    gro_file = "".join(all_gro)
    for idx, line in enumerate(gro_file.split('\n')):
        if len(line.split()) > 5:
            if line.startswith('ATOM') or line.startswith('HETATM'):
                residue_number = int(line[22:26])
                residue_name = line[17:21].strip()
                atom_name = line[11:16].strip()
                atom_number = int(line[6:11])
                atom_num = atom_num+1
                if residue_name in AA_ref.keys():
                    if prev_residue_number == -999:
                        prev_residue_number = residue_number
                        prev_residue_name = residue_name
                        num_atoms = 0
                if residue_name in protein_residues:
                    info["has_protein"] = True
                    if info["is_AA"] == None:
                        if atom_name in CG_list:
                            info["is_AA"] = False
                        else:
                            if prev_residue_number == residue_number:
                                num_atoms = num_atoms+1
                            else:
                                if prev_residue_name in AA_ref.keys():
                                    if num_atoms > AA_ref[prev_residue_name]:
                                        info["is_AA"] = True
                                    else:
                                        info["is_AA"] = False
                                else:
                                    prev_residue_number = -999
                elif residue_name in lipid_residues:
                    info["has_lipid"] = True
                elif residue_name in nucleic_residues:
                    info["has_nucleic"] = True
                elif residue_name in water_ion_residues:
                    info["has_water_ion"] = True
                elif residue_name in glucid_residues:
                    info["has_glucid"] = True
                # WALL particles
                elif residue_name in ["WAL"]:
                    pass
                else:
                    pass
                    #print(f"Unknown residue: {residue_name} / {str(gro_file_path)}")
    info["atom_number"] = atom_num
    if info["is_AA"] == None:
        info["is_AA"] = False
    return info

# %%
def get_coord_info(coord_file, source, gro_file_name='', gro_file_idx=0, GRO_FILE_NUMBER=0, ):
    if source=='gro':
        gro_info = extract_remote_info_from_gro(
                coord_file,
                gro_file_name,
                gro_file_idx,
                GRO_FILE_NUMBER,
                PROTEIN_RESIDUES,
                LIPID_RESIDUES,
                NUCLEIC_RESIDUES,
                WATER_ION_RESIDUES,
                GLUCID_RESIDUES
            )
    elif source=='pdb':
        gro_info = extract_remote_info_from_pdb(
            coord_file,
            gro_file_name,
            gro_file_idx,
            GRO_FILE_NUMBER,
            PROTEIN_RESIDUES,
            LIPID_RESIDUES,
            NUCLEIC_RESIDUES,
            WATER_ION_RESIDUES,
            GLUCID_RESIDUES
        )
    return gro_info

# %%
dico_file_types = read_query_file("../params/query.yml")

ext_gromacs = []
ext_namd = []
ext_amber = []

list_coordinate = []
list_trajectory = []
list_topology = []

for dico in dico_file_types:
    if dico["engine"] == "gromacs":
        ext_gromacs.append(dico["type"])
    elif dico["engine"] == "namd":
        ext_namd.append(dico["type"])
    elif dico["engine"] == "amber":
        ext_amber.append(dico["type"])
    
    if dico["category"] == "coordinate":
        list_coordinate.append(dico["type"])
    elif dico["category"] == "topology":
        list_topology.append(dico["type"])
    elif dico["category"] == "trajectory":
        list_trajectory.append(dico["type"])

ext_all = ext_gromacs + ext_namd + ext_amber
# The filetype "top" is included in both Gromacs and Amber. 
# And, the filetype "prm" is included in Namd and Amber.
# But, to simplify the analyses, I consider that "top" is only a filetype of Gromacs and prm a filetype of Namd.

# %%
PROTEIN_RESIDUES, LIPID_RESIDUES, NUCLEIC_RESIDUES, WATER_ION_RESIDUES, GLUCID_RESIDUES = read_residue_file(os.path.join("../params/residue_names.yml"))
# Out:
# Reading residue definition fom: ../params/residue_names.yml

# %%
zenodo_datasets = pd.read_csv(os.path.join(os.getcwd(), '../data', "zenodo_datasets.tsv"), sep="\t")
print(f'Number of datasets in zenodo: {len(zenodo_datasets)}')
figshare_datasets = pd.read_csv(os.path.join(os.getcwd(), '../data', "figshare_datasets.tsv"), sep="\t")
print(f'Number of datasets in figshare: {len(figshare_datasets)}')
all_datasets = pd.concat([zenodo_datasets, figshare_datasets], ignore_index=True)
print(f'Number of datasets in both: {len(all_datasets)}')

all_datasets['year'] = all_datasets['date_creation'].apply(lambda x: int(x.split('-')[0]))
#all_datasets
# Out:
# Number of datasets in zenodo: 873
# Number of datasets in figshare: 2006
# Number of datasets in both: 2879

# %%
zenodo_files = pd.read_csv(os.path.join(os.getcwd(), '../data', "zenodo_files.tsv"), sep="\t")
print(f'Number of files before cleaning in zenodo: {len(zenodo_files)}')
zenodo_files = clean_df(zenodo_files)
print(f'Number of files in zenodo: {len(zenodo_files)}')
figshare_files = pd.read_csv(os.path.join(os.getcwd(), '../data', "figshare_files.tsv"), sep="\t")
print(f'Number of files before cleaning in figshare: {len(figshare_files)}')
figshare_files = clean_df(figshare_files)
print(f'Number of files in figshare: {len(figshare_files)}')
all_files = pd.concat([zenodo_files, figshare_files], ignore_index=True)
print(f'Number of files in both: {len(all_files)}')
#all_files
# Out:
# /groups/sbinlab/tiemann/dev/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3166: DtypeWarning: Columns (4,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Number of files before cleaning in zenodo: 152868
# Number of files in zenodo: 152862
# Number of files before cleaning in figshare: 333283
# Number of files in figshare: 311941
# Number of files in both: 464803

# %%
all_df = pd.merge(all_datasets, all_files, on=['dataset_origin', 'dataset_id'], how='right')
#all_df

# %%
all_df["category"] = all_df["file_type"].apply(assign_file_category)
all_df["category"].value_counts()

all_df["engine_MD"] = all_df["file_type"].apply(assign_md_engine)
all_df["engine_MD"].value_counts()
# Out:
# none       395282
# gromacs     55080
# amber        7658
# namd         6783
# Name: engine_MD, dtype: int64

# %%
all_df['dataset_id_ori'] = all_df['dataset_origin'] + '_' + all_df['dataset_id'].astype(str)

# %% [markdown]
# # Statistics

# %% [markdown]
# ## Numbers

# %%
print(f"Number of datasets in zenodo: {len(all_datasets.loc[all_datasets['dataset_origin']=='zenodo', 'dataset_origin'])}")
print(f"Number of datasets in figshare: {len(all_datasets.loc[all_datasets['dataset_origin']=='figshare', 'dataset_origin'])}")
print(f"Number of datasets in both: {len(all_datasets.loc[all_datasets['dataset_origin'].isin(['figshare', 'zenodo']), 'dataset_origin'])}")
# Out:
# Number of datasets in zenodo: 873
# Number of datasets in figshare: 2006
# Number of datasets in both: 2879

# %%
print(f"Number of files in zenodo: {len(all_files.loc[all_files['dataset_origin']=='zenodo', 'dataset_origin'])}")
print(f"Number of files in figshare: {len(all_files.loc[all_files['dataset_origin']=='figshare', 'dataset_origin'])}")
print(f"Number of files in both: {len(all_files.loc[all_files['dataset_origin'].isin(['figshare', 'zenodo']), 'dataset_origin'])}")
# Out:
# Number of files in zenodo: 152862
# Number of files in figshare: 311941
# Number of files in both: 464803

# %%
print(f"Number of files in zenodo: \n{(all_df.loc[all_df['dataset_origin']=='zenodo', 'file_size']).describe()}")
print(f"Number of files in figshare: \n{(all_df.loc[all_df['dataset_origin']=='figshare', 'file_size']).describe()}")
print(f"Number of files in both: \n{(all_df.loc[all_df['dataset_origin'].isin(['figshare', 'zenodo']), 'file_size']).describe()}")
# Out:
# Number of files in zenodo:
# count    1.528620e+05
# mean     7.812160e+07
# std      9.143179e+08
# min      0.000000e+00
# 25%      6.800000e+03
# 50%      4.904000e+05
# 75%      7.700000e+06
# max      5.619977e+10
# Name: file_size, dtype: float64
# Number of files in figshare:
# count    4.513000e+03
# mean     1.763161e+08
# std      7.375295e+08
# min      5.000000e+00
# 25%      9.161800e+04
# 50%      3.205243e+06
# 75%      6.824028e+07
# max      1.720746e+10
# Name: file_size, dtype: float64
# Number of files in both:
# count    1.573750e+05
# mean     8.093750e+07
# std      9.098725e+08
# min      0.000000e+00
# 25%      7.800000e+03
# 50%      5.176000e+05
# 75%      7.837158e+06
# max      5.619977e+10
# Name: file_size, dtype: float64

# %%
print(f"Size of files in zenodo: {(all_df.loc[all_df['dataset_origin']=='zenodo', 'file_size']).sum()}")
print(f"Size of files in figshare: {(all_df.loc[all_df['dataset_origin']=='figshare', 'file_size']).sum()}")
print(f"Size of files in both: {(all_df.loc[all_df['dataset_origin'].isin(['figshare', 'zenodo']), 'file_size']).sum()}")
# Out:
# Size of files in zenodo: 11941824539219.0
# Size of files in figshare: 795714657760.0
# Size of files in both: 12737539196979.0

# %%
print(f"Number of zipfiles in zenodo: {len(all_files.loc[(all_files['dataset_origin']=='zenodo') & (all_files['file_type']=='zip'), 'dataset_origin'])}")
print(f"Number of zipfiles in figshare: {len(all_files.loc[(all_files['dataset_origin']=='figshare') & (all_files['file_type']=='zip'), 'dataset_origin'])}")
print(f"Number of zipfiles in both: {len(all_files.loc[(all_files['dataset_origin'].isin(['figshare', 'zenodo'])) & (all_files['file_type']=='zip'), 'dataset_origin'])}")
# Out:
# Number of zipfiles in zenodo: 1344
# Number of zipfiles in figshare: 1823
# Number of zipfiles in both: 3167

# %%
print(f"Size of zipfiles in zenodo: {(all_files.loc[(all_files['dataset_origin']=='zenodo') & (all_files['file_type']=='zip'), 'file_size']).sum()}")
print(f"Size of zipfiles in figshare: {(all_files.loc[(all_files['dataset_origin']=='figshare') & (all_files['file_type']=='zip'), 'file_size']).sum()}")
print(f"Size of zipfiles in both: {(all_files.loc[(all_files['dataset_origin'].isin(['figshare', 'zenodo'])) & (all_files['file_type']=='zip'), 'file_size']).sum()}")
# Out:
# Size of zipfiles in zenodo: 2372187319823.0
# Size of zipfiles in figshare: 185090397617.0
# Size of zipfiles in both: 2557277717440.0

# %%
print(f"Size of zipfiles in zenodo: \n{(all_files.loc[(all_files['dataset_origin']=='zenodo') & (all_files['file_type']=='zip'), 'file_size']).describe()}")
print(f"Size of zipfiles in figshare: \n{(all_files.loc[(all_files['dataset_origin']=='figshare') & (all_files['file_type']=='zip'), 'file_size']).describe()}")
print(f"Size of zipfiles in both: \n{(all_files.loc[(all_files['dataset_origin'].isin(['figshare', 'zenodo'])) & (all_files['file_type']=='zip'), 'file_size']).describe()}")
print(all_files.loc[(all_files['dataset_origin']=='figshare') & (all_files['file_type']=='zip'), 'file_size'].sum())
print(all_df.loc[(all_df['dataset_origin']=='figshare') & (all_df['file_type']=='zip'), 'file_size'].sum())
all_df.loc[(all_df['dataset_origin']=='figshare') & (all_df['file_type']=='zip') & (all_df['from_zip_file']==True)]
# Out:
# Size of zipfiles in zenodo:
# count    1.344000e+03
# mean     1.765020e+09
# std      3.733025e+09
# min      1.177000e+03
# 25%      6.034670e+07
# 50%      3.352578e+08
# 75%      1.977511e+09
# max      4.464433e+10
# Name: file_size, dtype: float64
# Size of zipfiles in figshare:
# count    1.770000e+03
# mean     1.045708e+08
# std      6.501742e+08
# min      4.580000e+02
# 25%      2.114065e+05
# 50%      3.808956e+06
# 75%      1.776786e+07
# max      1.720746e+10
# Name: file_size, dtype: float64
# Size of zipfiles in both:
# count    3.114000e+03
# mean     8.212196e+08
# std      2.632263e+09
# min      4.580000e+02
# 25%      8.392685e+05
# 50%      1.663913e+07
# 75%      3.260503e+08
# max      4.464433e+10
# Name: file_size, dtype: float64
# 185090397617.0
# 185090397617.0
#        dataset_origin  dataset_id                               doi  \
# 158255       figshare    14932766     10.1021/acs.jpcb.1c05320.s002
# 158256       figshare    14932766     10.1021/acs.jpcb.1c05320.s002
# 158257       figshare    14932766     10.1021/acs.jpcb.1c05320.s002
# 174767       figshare    12841135     10.1021/acs.jcim.0c00525.s002
# 174768       figshare    12841135     10.1021/acs.jcim.0c00525.s002
# 174772       figshare    12841135     10.1021/acs.jcim.0c00525.s002
# 175095       figshare    11764158   10.6084/m9.figshare.11764158.v2
# 175121       figshare    11764158   10.6084/m9.figshare.11764158.v2
# 175147       figshare    11764158   10.6084/m9.figshare.11764158.v2
# 175174       figshare    11764158   10.6084/m9.figshare.11764158.v2
# 175200       figshare    11764158   10.6084/m9.figshare.11764158.v2
# 175225       figshare    11764158   10.6084/m9.figshare.11764158.v2
# 184554       figshare    14364368   10.6084/m9.figshare.14364368.v2
# 184576       figshare    14364368   10.6084/m9.figshare.14364368.v2
# 184593       figshare    14364368   10.6084/m9.figshare.14364368.v2
# 184616       figshare    14364368   10.6084/m9.figshare.14364368.v2
# 184656       figshare    14364368   10.6084/m9.figshare.14364368.v2
# 184679       figshare    14364368   10.6084/m9.figshare.14364368.v2
# 201513       figshare    13030991     10.1021/acsomega.0c01295.s002
# 201675       figshare    16852600    10.3389/fchem.2021.736509.s002
# 202548       figshare     4675993     10.1021/acs.jpcc.7b00031.s001
# 202549       figshare     4675993     10.1021/acs.jpcc.7b00031.s001
# 202550       figshare     4675993     10.1021/acs.jpcc.7b00031.s001
# 203452       figshare     9879788  10.1021/acs.jpclett.9b02001.s002
# 204630       figshare    19027289     10.1021/acs.jcim.1c01424.s002
# 205680       figshare      118668      10.1371/journal.pcbi.1002708
# 210497       figshare     8079728     10.1021/acs.jcim.9b00045.s004
# 210498       figshare     8079728     10.1021/acs.jcim.9b00045.s004
# 210499       figshare     8079728     10.1021/acs.jcim.9b00045.s004
# 210500       figshare     8079728     10.1021/acs.jcim.9b00045.s004
# 211176       figshare    12469541     10.1021/acs.jpcb.0c02924.s002
# 211177       figshare    12469541     10.1021/acs.jpcb.0c02924.s002
# 211178       figshare    12469541     10.1021/acs.jpcb.0c02924.s002
# 211179       figshare    12469541     10.1021/acs.jpcb.0c02924.s002
# 211207       figshare    12469541     10.1021/acs.jpcb.0c02924.s002
# 211208       figshare    12469541     10.1021/acs.jpcb.0c02924.s002
# 233398       figshare     4040673     10.1021/acs.jctc.6b00595.s003
# 241338       figshare     3167305     10.1021/acs.iecr.5b04955.s001
# 241339       figshare     3167305     10.1021/acs.iecr.5b04955.s001
# 241340       figshare     3167305     10.1021/acs.iecr.5b04955.s001
# 241819       figshare     2046300            10.1021/jz5023619.s001
# 241821       figshare     2046300            10.1021/jz5023619.s001
# 241823       figshare     2046300            10.1021/jz5023619.s001
# 252675       figshare    12612358     10.1021/acs.jcim.0c00200.s002
# 258368       figshare    13348104     10.1021/acs.jctc.0c00752.s001
# 261010       figshare     2350840            10.1021/jp4048133.s001
# 278349       figshare    17430576     10.1021/acs.jcim.1c01010.s002
# 278688       figshare    14669430     10.1021/acs.jctc.1c00214.s002
# 278762       figshare    14755330     10.1021/acs.jctc.1c00103.s002
# 278763       figshare    14755330     10.1021/acs.jctc.1c00103.s002
# 278765       figshare    14755330     10.1021/acs.jctc.1c00103.s002
# 432280       figshare    16451470     10.1021/acs.jcim.1c00718.s001
# 433003       figshare    17879484     10.1021/acsomega.1c05465.s002
#
#        date_creation date_last_modified         date_fetched  file_number  \
# 158255    2021-07-08         2021-07-08  2022-04-29T00:44:50            1
# 158256    2021-07-08         2021-07-08  2022-04-29T00:44:50            1
# 158257    2021-07-08         2021-07-08  2022-04-29T00:44:50            1
# 174767    2020-08-21         2020-08-21  2022-04-29T00:45:07            1
# 174768    2020-08-21         2020-08-21  2022-04-29T00:45:07            1
# 174772    2020-08-21         2020-08-21  2022-04-29T00:45:07            1
# 175095    2020-01-29         2020-01-29  2022-04-29T00:45:12           10
# 175121    2020-01-29         2020-01-29  2022-04-29T00:45:12           10
# 175147    2020-01-29         2020-01-29  2022-04-29T00:45:12           10
# 175174    2020-01-29         2020-01-29  2022-04-29T00:45:12           10
# 175200    2020-01-29         2020-01-29  2022-04-29T00:45:12           10
# 175225    2020-01-29         2020-01-29  2022-04-29T00:45:12           10
# 184554    2021-04-03         2021-04-03  2022-04-29T00:45:59            1
# 184576    2021-04-03         2021-04-03  2022-04-29T00:45:59            1
# 184593    2021-04-03         2021-04-03  2022-04-29T00:45:59            1
# 184616    2021-04-03         2021-04-03  2022-04-29T00:45:59            1
# 184656    2021-04-03         2021-04-03  2022-04-29T00:45:59            1
# 184679    2021-04-03         2021-04-03  2022-04-29T00:45:59            1
# 201513    2020-10-01         2020-10-01  2022-04-29T00:46:58            1
# 201675    2021-10-22         2021-10-22  2022-04-29T00:47:00            1
# 202548    2017-02-21         2017-02-21  2022-04-29T00:47:19            1
# 202549    2017-02-21         2017-02-21  2022-04-29T00:47:19            1
# 202550    2017-02-21         2017-02-21  2022-04-29T00:47:19            1
# 203452    2019-09-19         2019-09-19  2022-04-29T00:47:30            1
# 204630    2022-01-24         2022-01-24  2022-04-29T00:47:35            1
# 205680    2012-10-18         2016-01-19  2022-04-29T00:47:39           13
# 210497    2019-05-03         2019-05-03  2022-04-29T00:48:06            1
# 210498    2019-05-03         2019-05-03  2022-04-29T00:48:06            1
# 210499    2019-05-03         2019-05-03  2022-04-29T00:48:06            1
# 210500    2019-05-03         2019-05-03  2022-04-29T00:48:06            1
# 211176    2020-06-11         2020-06-11  2022-04-29T00:48:13            1
# 211177    2020-06-11         2020-06-11  2022-04-29T00:48:13            1
# 211178    2020-06-11         2020-06-11  2022-04-29T00:48:13            1
# 211179    2020-06-11         2020-06-11  2022-04-29T00:48:13            1
# 211207    2020-06-11         2020-06-11  2022-04-29T00:48:13            1
# 211208    2020-06-11         2020-06-11  2022-04-29T00:48:13            1
# 233398    2016-10-19         2016-11-02  2022-04-29T00:49:15            1
# 241338    2016-04-08         2016-04-21  2022-04-29T00:49:15            1
# 241339    2016-04-08         2016-04-21  2022-04-29T00:49:15            1
# 241340    2016-04-08         2016-04-21  2022-04-29T00:49:15            1
# 241819    2015-12-17         2015-12-17  2022-04-29T00:49:26            1
# 241821    2015-12-17         2015-12-17  2022-04-29T00:49:26            1
# 241823    2015-12-17         2015-12-17  2022-04-29T00:49:26            1
# 252675    2020-07-05         2020-07-05  2022-04-29T00:49:46            1
# 258368    2020-12-08         2020-12-08  2022-04-29T00:50:04            1
# 261010    2016-02-18         2016-02-18  2022-04-29T00:50:30            1
# 278349    2021-12-23         2021-12-23  2022-04-29T00:51:46            1
# 278688    2021-05-24         2021-05-24  2022-04-29T00:51:50            1
# 278762    2021-06-09         2021-06-09  2022-04-29T00:51:50            1
# 278763    2021-06-09         2021-06-09  2022-04-29T00:51:50            1
# 278765    2021-06-09         2021-06-09  2022-04-29T00:51:50            1
# 432280    2021-08-26         2021-08-26  2022-04-29T00:52:34            1
# 433003    2022-01-05         2022-01-05  2022-04-29T00:52:43            1
#
#         download_number  view_number       license  ... file_type  file_size  \
# 158255               12           43  CC BY-NC 4.0  ...       zip        NaN
# 158256               12           43  CC BY-NC 4.0  ...       zip        NaN
# 158257               12           43  CC BY-NC 4.0  ...       zip        NaN
# 174767               11           66  CC BY-NC 4.0  ...       zip        NaN
# 174768               11           66  CC BY-NC 4.0  ...       zip        NaN
# 174772               11           66  CC BY-NC 4.0  ...       zip        NaN
# 175095             1139         3605     CC BY 4.0  ...       zip        NaN
# 175121             1139         3605     CC BY 4.0  ...       zip        NaN
# 175147             1139         3605     CC BY 4.0  ...       zip        NaN
# 175174             1139         3605     CC BY 4.0  ...       zip        NaN
# 175200             1139         3605     CC BY 4.0  ...       zip        NaN
# 175225             1139         3605     CC BY 4.0  ...       zip        NaN
# 184554                2           63     CC BY 4.0  ...       zip        NaN
# 184576                2           63     CC BY 4.0  ...       zip        NaN
# 184593                2           63     CC BY 4.0  ...       zip        NaN
# 184616                2           63     CC BY 4.0  ...       zip        NaN
# 184656                2           63     CC BY 4.0  ...       zip        NaN
# 184679                2           63     CC BY 4.0  ...       zip        NaN
# 201513                3           82  CC BY-NC 4.0  ...       zip        NaN
# 201675                2           11     CC BY 4.0  ...       zip        NaN
# 202548               28          155  CC BY-NC 4.0  ...       zip        NaN
# 202549               28          155  CC BY-NC 4.0  ...       zip        NaN
# 202550               28          155  CC BY-NC 4.0  ...       zip        NaN
# 203452               18          231  CC BY-NC 4.0  ...       zip        NaN
# 204630                2           25  CC BY-NC 4.0  ...       zip        NaN
# 205680              205          417     CC BY 4.0  ...       zip        NaN
# 210497               11          145  CC BY-NC 4.0  ...       zip        NaN
# 210498               11          145  CC BY-NC 4.0  ...       zip        NaN
# 210499               11          145  CC BY-NC 4.0  ...       zip        NaN
# 210500               11          145  CC BY-NC 4.0  ...       zip        NaN
# 211176               10          159  CC BY-NC 4.0  ...       zip        NaN
# 211177               10          159  CC BY-NC 4.0  ...       zip        NaN
# 211178               10          159  CC BY-NC 4.0  ...       zip        NaN
# 211179               10          159  CC BY-NC 4.0  ...       zip        NaN
# 211207               10          159  CC BY-NC 4.0  ...       zip        NaN
# 211208               10          159  CC BY-NC 4.0  ...       zip        NaN
# 233398               15          223  CC BY-NC 4.0  ...       zip        NaN
# 241338              216          264  CC BY-NC 4.0  ...       zip        NaN
# 241339              216          264  CC BY-NC 4.0  ...       zip        NaN
# 241340              216          264  CC BY-NC 4.0  ...       zip        NaN
# 241819               19          179  CC BY-NC 4.0  ...       zip        NaN
# 241821               19          179  CC BY-NC 4.0  ...       zip        NaN
# 241823               19          179  CC BY-NC 4.0  ...       zip        NaN
# 252675                4           58  CC BY-NC 4.0  ...       zip        NaN
# 258368               13           66  CC BY-NC 4.0  ...       zip        NaN
# 261010               36          210  CC BY-NC 4.0  ...       zip        NaN
# 278349                2           21  CC BY-NC 4.0  ...       zip        NaN
# 278688               17           28  CC BY-NC 4.0  ...       zip        NaN
# 278762                3            8  CC BY-NC 4.0  ...       zip        NaN
# 278763                3            8  CC BY-NC 4.0  ...       zip        NaN
# 278765                3            8  CC BY-NC 4.0  ...       zip        NaN
# 432280                9           24  CC BY-NC 4.0  ...       zip        NaN
# 433003                1           17  CC BY-NC 4.0  ...       zip        NaN
#
#        file_md5  from_zip_file  \
# 158255      NaN           True
# 158256      NaN           True
# 158257      NaN           True
# 174767      NaN           True
# 174768      NaN           True
# 174772      NaN           True
# 175095      NaN           True
# 175121      NaN           True
# 175147      NaN           True
# 175174      NaN           True
# 175200      NaN           True
# 175225      NaN           True
# 184554      NaN           True
# 184576      NaN           True
# 184593      NaN           True
# 184616      NaN           True
# 184656      NaN           True
# 184679      NaN           True
# 201513      NaN           True
# 201675      NaN           True
# 202548      NaN           True
# 202549      NaN           True
# 202550      NaN           True
# 203452      NaN           True
# 204630      NaN           True
# 205680      NaN           True
# 210497      NaN           True
# 210498      NaN           True
# 210499      NaN           True
# 210500      NaN           True
# 211176      NaN           True
# 211177      NaN           True
# 211178      NaN           True
# 211179      NaN           True
# 211207      NaN           True
# 211208      NaN           True
# 233398      NaN           True
# 241338      NaN           True
# 241339      NaN           True
# 241340      NaN           True
# 241819      NaN           True
# 241821      NaN           True
# 241823      NaN           True
# 252675      NaN           True
# 258368      NaN           True
# 261010      NaN           True
# 278349      NaN           True
# 278688      NaN           True
# 278762      NaN           True
# 278763      NaN           True
# 278765      NaN           True
# 432280      NaN           True
# 433003      NaN           True
#
#                                                 file_name  file_url  \
# 158255               SI-ZIP/MD_Cavity/ani-HypD-50.pdb.zip       NaN
# 158256                SI-ZIP/MD_Cavity/Caver_analysis.zip       NaN
# 158257               SI-ZIP/MD_Cavity/zwi-HypD-50.pdb.zip       NaN
# 174767  Supplementary_Materials/Tables_performance_POP...       NaN
# 174768  Supplementary_Materials/Partial_Dependence_Plo...       NaN
# 174772         Supplementary_Materials/gromacs_inputs.zip       NaN
# 175095               QHD_LP6/other_files/centroid_QHD.zip       NaN
# 175121               QHD_LP5/other_files/centroid_QHD.zip       NaN
# 175147               QHD_LP4/other_files/centroid_QHD.zip       NaN
# 175174               QHD_LP3/other_files/centroid_QHD.zip       NaN
# 175200               QHD_LP2/other_files/centroid_QHD.zip       NaN
# 175225               QHD_LP1/other_files/centroid_QHD.zip       NaN
# 184554  p-p interaction/WITH 8 HDS/cluspro.510950.000....       NaN
# 184576             simulation data/checkwiththisfiles.zip       NaN
# 184593     simulation data/simulation data/propkafile.zip       NaN
# 184616  simulation data/simulation data/NEW DATA/recon...       NaN
# 184656                         propka/data/propkafile.zip       NaN
# 184679     propka/data/NEW DATA/reconverttopropkafile.zip       NaN
# 201513       Raw_data/RatSA homology/RatSA_2018-11-09.zip       NaN
# 201675  Supplementary data/conformers/min/Potential en...       NaN
# 202548                        IZA_zeolite_Block_Files.zip       NaN
# 202549                                    cif_zeo_opt.zip       NaN
# 202550                     Gulp_optimized_Block_Files.zip       NaN
# 203452                                SI_data/scripts.zip       NaN
# 204630                     input_files/MD_input_files.zip       NaN
# 205680  caver_3.0/source_code/caver/lib/junit/junit-3....       NaN
# 210497                                         apo-wt.zip       NaN
# 210498                                        mut-DFB.zip       NaN
# 210499                                         wt-DFB.zip       NaN
# 210500                                      wt-m-MPEP.zip       NaN
# 211176  jp-2020-02924j_SI/Demo-w-Example-Data/FastFlop...       NaN
# 211177  jp-2020-02924j_SI/Demo-w-Example-Data/FastFlop...       NaN
# 211178  jp-2020-02924j_SI/Demo-w-Example-Data/FastFlop...       NaN
# 211179  jp-2020-02924j_SI/Demo-w-Example-Data/FastFlop...       NaN
# 211207  jp-2020-02924j_SI/Demo-w-Example-Data/AbInitio...       NaN
# 211208  jp-2020-02924j_SI/Demo-w-Example-Data/AbInitio...       NaN
# 233398  espressopp-1.0/contrib/boost/libs/smart_ptr/sm...       NaN
# 241338                               MD-conformations.zip       NaN
# 241339                        COSMOconf-conformations.zip       NaN
# 241340          COSMOfiles-optimised-MD-conformations.zip       NaN
# 241819                     h1280x720/Sim2-movie-1.pdb.zip       NaN
# 241821                     h1280x720/Sim3-movie-1.pdb.zip       NaN
# 241823                     h1280x720/Sim3-movie-2.pdb.zip       NaN
# 252675                        pKI_pIC50_Imatinib/RMSD.zip       NaN
# 258368                               si_moldart/blues.zip       NaN
# 261010                                       SuppInfo.zip       NaN
# 278349                         colvars_neural_network.zip       NaN
# 278688                SI_content_rev/amber18_examples.zip       NaN
# 278762                        SI/chignolin gawtm eabf.zip       NaN
# 278763                            SI/custom_potential.zip       NaN
# 278765                      SI/colvars amdreweighting.zip       NaN
# 432280                       Force_Field_Files/G4_AM1.zip       NaN
# 433003                                 rdl_models_mds.zip       NaN
#
#                                           origin_zip_file category engine_MD  \
# 158255                               jp1c05320_si_002.zip     none      none
# 158256                               jp1c05320_si_002.zip     none      none
# 158257                               jp1c05320_si_002.zip     none      none
# 174767                               ci0c00525_si_002.zip     none      none
# 174768                               ci0c00525_si_002.zip     none      none
# 174772                               ci0c00525_si_002.zip     none      none
# 175095                                        QHD_LP6.zip     none      none
# 175121                                        QHD_LP5.zip     none      none
# 175147                                        QHD_LP4.zip     none      none
# 175174                                        QHD_LP3.zip     none      none
# 175200                                        QHD_LP2.zip     none      none
# 175225                                        QHD_LP1.zip     none      none
# 184554  8-Hydroxydihydrosanguinarine (8-HDS), a pyrido...     none      none
# 184576  8-Hydroxydihydrosanguinarine (8-HDS), a pyrido...     none      none
# 184593  8-Hydroxydihydrosanguinarine (8-HDS), a pyrido...     none      none
# 184616  8-Hydroxydihydrosanguinarine (8-HDS), a pyrido...     none      none
# 184656  8-Hydroxydihydrosanguinarine (8-HDS), a pyrido...     none      none
# 184679  8-Hydroxydihydrosanguinarine (8-HDS), a pyrido...     none      none
# 201513                               ao0c01295_si_002.zip     none      none
# 201675  DataSheet2_Scaffold Searching of FDA and EMA-A...     none      none
# 202548                               jp7b00031_si_001.zip     none      none
# 202549                               jp7b00031_si_001.zip     none      none
# 202550                               jp7b00031_si_001.zip     none      none
# 203452                               jz9b02001_si_002.zip     none      none
# 204630                               ci1c01424_si_002.zip     none      none
# 205680                                    Software_S1.zip     none      none
# 210497                               ci9b00045_si_004.zip     none      none
# 210498                               ci9b00045_si_004.zip     none      none
# 210499                               ci9b00045_si_004.zip     none      none
# 210500                               ci9b00045_si_004.zip     none      none
# 211176                               jp0c02924_si_002.zip     none      none
# 211177                               jp0c02924_si_002.zip     none      none
# 211178                               jp0c02924_si_002.zip     none      none
# 211179                               jp0c02924_si_002.zip     none      none
# 211207                               jp0c02924_si_002.zip     none      none
# 211208                               jp0c02924_si_002.zip     none      none
# 233398                               ct6b00595_si_003.zip     none      none
# 241338                               ie5b04955_si_001.zip     none      none
# 241339                               ie5b04955_si_001.zip     none      none
# 241340                               ie5b04955_si_001.zip     none      none
# 241819                               jz5023619_si_001.zip     none      none
# 241821                               jz5023619_si_001.zip     none      none
# 241823                               jz5023619_si_001.zip     none      none
# 252675                               ci0c00200_si_002.zip     none      none
# 258368                               ct0c00752_si_001.zip     none      none
# 261010                               jp4048133_si_001.zip     none      none
# 278349                               ci1c01010_si_002.zip     none      none
# 278688                               ct1c00214_si_002.zip     none      none
# 278762                               ct1c00103_si_002.zip     none      none
# 278763                               ct1c00103_si_002.zip     none      none
# 278765                               ct1c00103_si_002.zip     none      none
# 432280                               ci1c00718_si_001.zip     none      none
# 433003                               ao1c05465_si_002.zip     none      none
#
#            dataset_id_ori
# 158255  figshare_14932766
# 158256  figshare_14932766
# 158257  figshare_14932766
# 174767  figshare_12841135
# 174768  figshare_12841135
# 174772  figshare_12841135
# 175095  figshare_11764158
# 175121  figshare_11764158
# 175147  figshare_11764158
# 175174  figshare_11764158
# 175200  figshare_11764158
# 175225  figshare_11764158
# 184554  figshare_14364368
# 184576  figshare_14364368
# 184593  figshare_14364368
# 184616  figshare_14364368
# 184656  figshare_14364368
# 184679  figshare_14364368
# 201513  figshare_13030991
# 201675  figshare_16852600
# 202548   figshare_4675993
# 202549   figshare_4675993
# 202550   figshare_4675993
# 203452   figshare_9879788
# 204630  figshare_19027289
# 205680    figshare_118668
# 210497   figshare_8079728
# 210498   figshare_8079728
# 210499   figshare_8079728
# 210500   figshare_8079728
# 211176  figshare_12469541
# 211177  figshare_12469541
# 211178  figshare_12469541
# 211179  figshare_12469541
# 211207  figshare_12469541
# 211208  figshare_12469541
# 233398   figshare_4040673
# 241338   figshare_3167305
# 241339   figshare_3167305
# 241340   figshare_3167305
# 241819   figshare_2046300
# 241821   figshare_2046300
# 241823   figshare_2046300
# 252675  figshare_12612358
# 258368  figshare_13348104
# 261010   figshare_2350840
# 278349  figshare_17430576
# 278688  figshare_14669430
# 278762  figshare_14755330
# 278763  figshare_14755330
# 278765  figshare_14755330
# 432280  figshare_16451470
# 433003  figshare_17879484
#
# [53 rows x 22 columns]

# %% [markdown]
# # Get traj datasets

# %%
traj_df = all_df.copy()
traj_df = traj_df.loc[traj_df['category']=='trajectory'].reset_index(drop=True)

traj_df_from_zip = traj_df.copy()
traj_df_from_zip = traj_df_from_zip.loc[traj_df_from_zip['from_zip_file']==True].reset_index(drop=True)
traj_df_no_zip = traj_df.copy()
traj_df_no_zip = traj_df_no_zip.loc[traj_df_no_zip['from_zip_file']==False].reset_index(drop=True)
traj_df_no_zip
# Out:
#      dataset_origin  dataset_id                              doi  \
# 0            zenodo      495247            10.5281/zenodo.495247
# 1            zenodo      495247            10.5281/zenodo.495247
# 2            zenodo      495247            10.5281/zenodo.495247
# 3            zenodo      495247            10.5281/zenodo.495247
# 4            zenodo     4352287           10.5281/zenodo.4352287
# ...             ...         ...                              ...
# 5385       figshare    17056145  10.6084/m9.figshare.17056145.v1
# 5386       figshare    17056145  10.6084/m9.figshare.17056145.v1
# 5387       figshare    17056145  10.6084/m9.figshare.17056145.v1
# 5388       figshare     7217726   10.6084/m9.figshare.7217726.v1
# 5389       figshare    13140482  10.6084/m9.figshare.13140482.v2
#
#      date_creation date_last_modified         date_fetched  file_number  \
# 0       2017-04-17         2020-01-21  2022-04-28T22:43:20            5
# 1       2017-04-17         2020-01-21  2022-04-28T22:43:20            5
# 2       2017-04-17         2020-01-21  2022-04-28T22:43:20            5
# 3       2017-04-17         2020-01-21  2022-04-28T22:43:20            5
# 4       2020-12-18         2020-12-19  2022-04-28T22:43:20            2
# ...            ...                ...                  ...          ...
# 5385    2021-11-22         2021-11-22  2022-04-29T00:43:59           15
# 5386    2021-11-22         2021-11-22  2022-04-29T00:43:59           15
# 5387    2021-11-22         2021-11-22  2022-04-29T00:43:59           15
# 5388    2018-10-17         2018-10-17  2022-04-29T00:44:00            1
# 5389    2021-03-05         2021-03-05  2022-04-29T00:44:00           24
#
#       download_number  view_number    license  ... file_type     file_size  \
# 0                  29           22  CC-BY-4.0  ...       edr  1.591384e+06
# 1                  29           22  CC-BY-4.0  ...       xtc  5.867509e+08
# 2                  29           22  CC-BY-4.0  ...       edr  1.591384e+06
# 3                  29           22  CC-BY-4.0  ...       xtc  5.867548e+08
# 4                  14           25  CC-BY-4.0  ...       xtc  1.362350e+10
# ...               ...          ...        ...  ...       ...           ...
# 5385                1           18  CC BY 4.0  ...        nc  2.704000e+03
# 5386                1           18  CC BY 4.0  ...        nc  3.814880e+05
# 5387                1           18  CC BY 4.0  ...        nc  3.814880e+05
# 5388              588          647  CC BY 4.0  ...        nc  3.110905e+09
# 5389               19           85  CC BY 4.0  ...        nc  3.606652e+06
#
#                               file_md5  from_zip_file           file_name  \
# 0     3f592c232aa0487dbd534fe2e309563c          False  md50ns_chunk01.edr
# 1     afe83c617ac83b2923b0e135bfed2f3e          False  md50ns_chunk01.xtc
# 2     f9a433c460e08e75c91f18569b632057          False  md50ns_chunk02.edr
# 3     a36878a526ba916a86e2fea18925193f          False  md50ns_chunk02.xtc
# 4     de899753a8274a8cb0d6e0e407104dfb          False    purepopccent.xtc
# ...                                ...            ...                 ...
# 5385  35439bca805eb698d112cf1f28ab9e83          False         Figure10.nc
# 5386  26fc1db119c827f33240fb193fc88bc7          False         Figure8a.nc
# 5387  1817b9bbe5186ba3163c6ce095534e57          False         Figure8d.nc
# 5388  5b18c1ad901a15dc56e519132669a9c8          False    EmissionClump.nc
# 5389  2da76033282c90ae78726bfa0fff918f          False      SST20140124.nc
#
#                                                file_url origin_zip_file  \
# 0     https://zenodo.org/api/files/06706527-b59a-449...            none
# 1     https://zenodo.org/api/files/06706527-b59a-449...            none
# 2     https://zenodo.org/api/files/06706527-b59a-449...            none
# 3     https://zenodo.org/api/files/06706527-b59a-449...            none
# 4     https://zenodo.org/api/files/2f4d99e4-5c1c-493...            none
# ...                                                 ...             ...
# 5385    https://ndownloader.figshare.com/files/31545164            None
# 5386    https://ndownloader.figshare.com/files/31545179            None
# 5387    https://ndownloader.figshare.com/files/31545185            None
# 5388    https://ndownloader.figshare.com/files/13291901            None
# 5389    https://ndownloader.figshare.com/files/25267682            None
#
#         category engine_MD     dataset_id_ori
# 0     trajectory   gromacs      zenodo_495247
# 1     trajectory   gromacs      zenodo_495247
# 2     trajectory   gromacs      zenodo_495247
# 3     trajectory   gromacs      zenodo_495247
# 4     trajectory   gromacs     zenodo_4352287
# ...          ...       ...                ...
# 5385  trajectory     amber  figshare_17056145
# 5386  trajectory     amber  figshare_17056145
# 5387  trajectory     amber  figshare_17056145
# 5388  trajectory     amber   figshare_7217726
# 5389  trajectory     amber  figshare_13140482
#
# [5390 rows x 22 columns]

# %%
# checkout struc for content & number of atoms
# get size of traj
# get number of struc & traj in dataset

# %%
if os.path.exists(os.path.join(os.getcwd(), '../data', 'dataset_info.tsv')):
    infos = pd.read_csv(os.path.join(os.getcwd(), '../data', 'dataset_info.tsv'), sep="\t")
    already_checked = list(infos['dataset_id_ori'].unique())
else:
    infos = [['dataset_id_ori', 'category', 'file_name', 'file_type', 'size', 'url', 'atom_num', 
          'has_protein', 'has_nucleic', 'has_lipid', 'has_water_ion', 'has_glucid', 'is_AA']]
    with open(os.path.join(os.getcwd(), '../data', 'dataset_info.tsv'), 'w') as fp:
        fp.write("\t".join(infos[0])+"\n")
    already_checked = []

for ins, dataset_id_ori in enumerate(traj_df_no_zip['dataset_id_ori'].unique()):
    if not (dataset_id_ori in already_checked):
        print(f"{ins}/{len(traj_df_no_zip['dataset_id_ori'].unique())}")
        dataset_files = all_df.loc[all_df['dataset_id_ori']==dataset_id_ori]
        coordinate_files = dataset_files.loc[dataset_files['category']=='coordinate']
        coordinate_files = dataset_files.loc[dataset_files['file_type'].isin(['gro', 'pdb'])].reset_index(drop=True)
        coordinate_files = coordinate_files.dropna(subset=['file_url']).reset_index(drop=True)
        if len(coordinate_files)>0:
            for index, row in coordinate_files.iterrows():
                source = row['file_type']
                infile=row['file_url']
                rdr = get_coord_info(infile, source, 
                               gro_file_name=f'{row["dataset_origin"]}|{row["dataset_id"]}|{infile.split("/")[-1]}', 
                               gro_file_idx=index, GRO_FILE_NUMBER=len(coordinate_files))
                if rdr['is_AA']==True:
                    print(rdr)
                new_line = [
                    dataset_id_ori, 'coordinate', rdr['filename'], source, row['file_size'], infile, rdr['atom_number'],
                    rdr['has_protein'], rdr['has_nucleic'], rdr['has_lipid'], rdr['has_water_ion'], rdr['has_glucid'], rdr['is_AA'],
                ]
                #infos.append(new_line)
                
                with open(os.path.join(os.getcwd(), '../data', 'dataset_info.tsv'), 'a') as fp:
                    fp.write("\t".join([str(el) for el in new_line])+"\n")
            sub_traj_df_no_zip = traj_df_no_zip.loc[traj_df_no_zip['dataset_id_ori']==dataset_id_ori]
            sub_traj_df_no_zip = sub_traj_df_no_zip.loc[sub_traj_df_no_zip['category']=='trajectory']
            sub_traj_df_no_zip = sub_traj_df_no_zip.loc[sub_traj_df_no_zip['file_type'].isin(['xtc', 'trr'])].reset_index(drop=True)
            sub_traj_df_no_zip
            for index, row in sub_traj_df_no_zip.iterrows():
                infile=row['file_url']
                new_line = [
                    dataset_id_ori, 'trajectory', row['file_name'], 'xtc', row['file_size'], row['file_url'], None,
                    None, None, None, None, None, None,
                ]
                #infos.append(new_line)
                with open(os.path.join(os.getcwd(), '../data', 'dataset_info.tsv'), 'a') as fp:
                    fp.write("\t".join([str(el) for el in new_line])+"\n")
            already_checked.append(dataset_id_ori)
# if len(infos) > 1:
#     infos_df = pd.DataFrame(data=infos[1:], columns=infos[0])
#     infos_df.to_csv(os.path.join(os.getcwd(), '../data', 'dataset_info.tsv'), sep="\t")
# infos
# Out:
# ['zenodo_3965660', 'zenodo_4115152', 'zenodo_1219366', 'zenodo_4388378', 'zenodo_3956812', 'zenodo_14066', 'zenodo_3956814', 'zenodo_51760', 'zenodo_45007', 'zenodo_4607770', 'zenodo_34415', 'zenodo_12743', 'zenodo_4674308', 'zenodo_14591', 'zenodo_4114065', 'zenodo_30898', 'zenodo_1129435', 'zenodo_4114641', 'zenodo_4501251', 'zenodo_3966452', 'zenodo_32173', 'zenodo_3956709', 'zenodo_13934', 'zenodo_4607833', 'zenodo_13814', 'zenodo_35156', 'zenodo_3956775', 'zenodo_4643634', 'zenodo_4522359', 'zenodo_4114422', 'zenodo_4643914', 'zenodo_229332', 'zenodo_4445375', 'zenodo_2640439', 'zenodo_16291', 'zenodo_3760965', 'zenodo_1468560', 'zenodo_1009094', 'zenodo_887398', 'zenodo_4643862', 'zenodo_1219468', 'zenodo_259392', 'zenodo_15550', 'zenodo_32498', 'zenodo_3483793', 'zenodo_4644028', 'zenodo_35193', 'zenodo_1488102', 'zenodo_2641987', 'zenodo_2653859', 'zenodo_1293891', 'zenodo_44622', 'zenodo_2653735', 'zenodo_45008', 'zenodo_1198454', 'zenodo_3871590', 'zenodo_1402417', 'zenodo_3855729', 'zenodo_15549', 'zenodo_3754109', 'zenodo_1182654', 'zenodo_3557669', 'zenodo_247199', 'zenodo_3592499', 'zenodo_3247366', 'zenodo_1205468', 'zenodo_16289', 'zenodo_44660', 'zenodo_825383', 'zenodo_14595', 'zenodo_1487895', 'zenodo_3888436', 'zenodo_3756664', 'zenodo_259376', 'zenodo_3236015', 'zenodo_1293941', 'zenodo_1487906', 'zenodo_1129419', 'zenodo_229750', 'zenodo_3756668', 'zenodo_1424290', 'zenodo_1111822', 'zenodo_16485', 'zenodo_1493190', 'zenodo_1404040', 'zenodo_2653723', 'zenodo_16287', 'zenodo_1306821', 'zenodo_3725637', 'zenodo_1043956', 'zenodo_1288297', 'zenodo_1129431', 'zenodo_3888383', 'zenodo_51754', 'zenodo_4071451', 'zenodo_4040423', 'zenodo_259343', 'zenodo_3448608', 'zenodo_3997019', 'zenodo_345321', 'zenodo_1205520', 'zenodo_1010142', 'zenodo_30865', 'zenodo_238943', 'zenodo_3871008', 'zenodo_3604289', 'zenodo_1488094', 'zenodo_4643985', 'zenodo_3874378', 'zenodo_3778112', 'zenodo_4740788', 'zenodo_53212', 'zenodo_164206', 'zenodo_3871006', 'zenodo_12767', 'zenodo_35159', 'zenodo_4116245', 'zenodo_4643616', 'zenodo_5997385', 'zenodo_6535604', 'zenodo_4445314', 'zenodo_3247443', 'zenodo_4492639', 'zenodo_1020623', 'zenodo_3754180', 'zenodo_1424381', 'zenodo_16294', 'zenodo_1129439', 'zenodo_13287', 'zenodo_1293957', 'zenodo_887396', 'zenodo_1205387', 'zenodo_1009027', 'zenodo_259365', 'zenodo_55565', 'zenodo_164203', 'zenodo_259354', 'zenodo_3857816', 'zenodo_3604384', 'zenodo_1118682', 'zenodo_13944', 'zenodo_1020671', 'zenodo_1198158', 'zenodo_2562079', 'zenodo_4494358', 'zenodo_1487761', 'zenodo_259335', 'zenodo_3741793', 'zenodo_1182658', 'zenodo_3247396', 'zenodo_3613573', 'zenodo_887400', 'zenodo_1293905', 'zenodo_32144', 'zenodo_1219494', 'zenodo_1283333', 'zenodo_1423304', 'zenodo_3888333', 'zenodo_1010438', 'zenodo_3335503', 'zenodo_6526200', 'zenodo_16254', 'zenodo_3891388', 'zenodo_247203', 'zenodo_3965801', 'zenodo_3965807', 'zenodo_3332778', 'zenodo_3693681', 'zenodo_825064', 'zenodo_17228', 'zenodo_1409551', 'zenodo_1011104', 'zenodo_3985089', 'zenodo_1010238', 'zenodo_1010232', 'zenodo_3997116', 'zenodo_3871004', 'zenodo_3965596', 'zenodo_3604731', 'zenodo_1043926', 'zenodo_1293855', 'zenodo_1020689', 'zenodo_247204', 'zenodo_240735', 'zenodo_4643632', 'zenodo_53222', 'zenodo_838635', 'zenodo_35074', 'zenodo_1244109', 'zenodo_1020593', 'zenodo_3248620', 'zenodo_838633', 'zenodo_3833725', 'zenodo_825389', 'zenodo_3997135', 'zenodo_16293', 'zenodo_4643899', 'zenodo_1293932', 'zenodo_825387', 'zenodo_3966306', 'zenodo_14880', 'zenodo_4439339', 'zenodo_4071264', 'zenodo_2653815', 'zenodo_50904', 'zenodo_3604448', 'zenodo_1129458', 'zenodo_4537207', 'zenodo_13853', 'zenodo_1043946', 'zenodo_1118980', 'zenodo_1010406', 'zenodo_4643875', 'zenodo_3604139', 'zenodo_4770527', 'zenodo_4607786', 'zenodo_3956797', 'zenodo_1205549', 'zenodo_14594', 'zenodo_1219413', 'zenodo_3557469', 'zenodo_1230390', 'zenodo_3572241', 'zenodo_5734452', 'zenodo_229254', 'zenodo_838219', 'zenodo_3539129', 'zenodo_247202', 'zenodo ...
# 0/996
# 1/996
# 2/996
# 3/996
# 4/996
# 5/996
# 6/996
# 7/996
# 12/996
# 13/996
# 14/996
# 72/996
# Reading 0/1 https://zenodo.org/api/files/44aeb435-bb28-4a17-a866-1259d0975bfe/popcRUN3.gro
# 73/996
# 76/996
# Reading  0/10 https://zenodo.org/api/files/7cb639f6-f520-44f3-a62a-c0f1d76f9a9a/start.gro
# Reading  1/10 https://zenodo.org/api/files/7cb639f6-f520-44f3-a62a-c0f1d76f9a9a/ternary_2_4_10.gro
# Reading  2/10 https://zenodo.org/api/files/7cb639f6-f520-44f3-a62a-c0f1d76f9a9a/ternary_2_4_20.gro
# Reading  3/10 https://zenodo.org/api/files/7cb639f6-f520-44f3-a62a-c0f1d76f9a9a/ternary_2_4_30.gro
# Reading  4/10 https://zenodo.org/api/files/7cb639f6-f520-44f3-a62a-c0f1d76f9a9a/ternary_2_6_10.gro
# Reading  5/10 https://zenodo.org/api/files/7cb639f6-f520-44f3-a62a-c0f1d76f9a9a/ternary_2_6_20.gro
# Reading  6/10 https://zenodo.org/api/files/7cb639f6-f520-44f3-a62a-c0f1d76f9a9a/ternary_2_6_30.gro
# Reading  7/10 https://zenodo.org/api/files/7cb639f6-f520-44f3-a62a-c0f1d76f9a9a/ternary_2_8_10.gro
# Reading  8/10 https://zenodo.org/api/files/7cb639f6-f520-44f3-a62a-c0f1d76f9a9a/ternary_2_8_20.gro
# Reading  9/10 https://zenodo.org/api/files/7cb639f6-f520-44f3-a62a-c0f1d76f9a9a/ternary_2_8_30.gro
# 77/996
# Reading 0/1 https://zenodo.org/api/files/ffc85d08-ade5-43b8-b893-f8d2af80ea15/pope.gro
# 87/996
# Reading 0/1 https://zenodo.org/api/files/ff8ac508-7e21-4492-8600-6b416e88a9b6/00-CER160_9_POPC_512_TM3_10_5up_5down_NaCl_150mM_310K_eq.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '1423207', 'atom_number': 177171, 'has_protein': True, 'has_nucleic': False, 'has_lipid': True, 'has_water_ion': True, 'has_glucid': False, 'filename': '00-CER160_9_POPC_512_TM3_10_5up_5down_NaCl_150mM_310K_eq.gro', 'is_AA': True}
# 88/996
# Reading 0/2 https://zenodo.org/api/files/50ffc081-d135-4d74-9fe1-2991b538adec/00-POPC_512_WALP23_10_5up_5down_NaCl_150mMol_eq.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '3247322', 'atom_number': 133888, 'has_protein': True, 'has_nucleic': False, 'has_lipid': True, 'has_water_ion': True, 'has_glucid': False, 'filename': '00-POPC_512_WALP23_10_5up_5down_NaCl_150mMol_eq.gro', 'is_AA': True}
# Reading 1/2 https://zenodo.org/api/files/50ffc081-d135-4d74-9fe1-2991b538adec/01-POPC_512_WALP23_10_5up_5down_NaCl_150mM_310K_md.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '3247322', 'atom_number': 133888, 'has_protein': True, 'has_nucleic': False, 'has_lipid': True, 'has_water_ion': True, 'has_glucid': False, 'filename': '01-POPC_512_WALP23_10_5up_5down_NaCl_150mM_310K_md.gro', 'is_AA': True}
# 89/996
# Reading 0/1 https://zenodo.org/api/files/525d0d65-2049-43ab-a6c2-aad91e9dd4a9/100ns.gro
# 93/996
# Reading 0/2 https://zenodo.org/api/files/3e327734-7398-4c36-8b1d-7be840a6f945/md-pope_43A1-S3_313K_v1.gro
# Reading 1/2 https://zenodo.org/api/files/3e327734-7398-4c36-8b1d-7be840a6f945/md-pope_43A1-S3_313K_v2.gro
# 99/996
# Reading 0/1 https://zenodo.org/api/files/12f31839-27af-40a8-bb34-0719b39d31e7/run.gro
# 105/996
# Reading 0/7 https://zenodo.org/api/files/38edbf3a-484f-4785-9e97-11372b4d9b30/M1_anneal.gro
# Reading 1/7 https://zenodo.org/api/files/38edbf3a-484f-4785-9e97-11372b4d9b30/M2_anneal.gro
# Reading 2/7 https://zenodo.org/api/files/38edbf3a-484f-4785-9e97-11372b4d9b30/M3_anneal.gro
# Reading 3/7 https://zenodo.org/api/files/38edbf3a-484f-4785-9e97-11372b4d9b30/M4_anneal.gro
# Reading 4/7 https://zenodo.org/api/files/38edbf3a-484f-4785-9e97-11372b4d9b30/M5_anneal.gro
# Reading 5/7 https://zenodo.org/api/files/38edbf3a-484f-4785-9e97-11372b4d9b30/M6_anneal.gro
# Reading 6/7 https://zenodo.org/api/files/38edbf3a-484f-4785-9e97-11372b4d9b30/M7_anneal.gro
# 109/996
# 113/996
# 122/996
# 123/996
# 137/996
# 139/996
# 176/996
# 185/996
# 196/996
# 199/996
# Reading 0/1 https://zenodo.org/api/files/e8905e46-42c2-40a9-93e2-4edbb497b80d/run.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '1010352', 'atom_number': 37231, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': True, 'has_glucid': False, 'filename': 'run.gro', 'is_AA': True}
# 275/996
# 316/996
# 329/996
# 369/996
# 393/996
# 404/996
# 406/996
# 414/996
# 415/996
# 416/996
# 417/996
# 418/996
# 419/996
# 420/996
# 421/996
# 422/996
# 423/996
# 424/996
# 425/996
# 426/996
# 427/996
# 428/996
# 429/996
# 430/996
# 432/996
# 433/996
# 434/996
# 435/996
# 436/996
# 437/996
# 446/996
# 457/996
# Reading 0/1 https://zenodo.org/api/files/05731ef9-0e6b-4c39-a681-17395dc135ee/run.gro
# 464/996
# 469/996
# 472/996
# Reading 0/1 https://zenodo.org/api/files/2d275c3c-8595-420d-9431-721026fec267/firstframe_fix.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '6478270', 'atom_number': 9650, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': True, 'has_glucid': False, 'filename': 'firstframe_fix.gro', 'is_AA': True}
# 473/996
# Reading 0/2 https://zenodo.org/api/files/067473d1-eea4-4dbf-852c-88d1fbdf4e52/input_gromacs.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '1307420', 'atom_number': 30104, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': True, 'has_glucid': False, 'filename': 'input_gromacs.gro', 'is_AA': True}
# Reading 1/2 https://zenodo.org/api/files/067473d1-eea4-4dbf-852c-88d1fbdf4e52/protein.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '1307420', 'atom_number': 1332, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': False, 'has_glucid': False, 'filename': 'protein.gro', 'is_AA': True}
# 474/996
# Reading 0/2 https://zenodo.org/api/files/66258dd5-e52a-4470-aaea-294cf7746f45/input_gromacs.gro
# Reading 1/2 https://zenodo.org/api/files/66258dd5-e52a-4470-aaea-294cf7746f45/input_pre-miR20b.pdb
# 475/996
# Reading 0/1 https://zenodo.org/api/files/fbdf6cbd-8a89-4d53-bbf2-0b439c1b9a23/input.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '1308045', 'atom_number': 30749, 'has_protein': True, 'has_nucleic': True, 'has_lipid': False, 'has_water_ion': True, 'has_glucid': False, 'filename': 'input.gro', 'is_AA': True}
# 476/996
# Reading 0/1 https://zenodo.org/api/files/c6ac3162-2b87-4b6f-be1c-ff624ba5f777/psi_md_traj.gro
# 477/996
# Reading 0/3 https://zenodo.org/api/files/e55baaab-f6cc-4643-bfc4-3f49de027eea/SpikeD614G-SIRAH.gro
# Reading 1/3 https://zenodo.org/api/files/e55baaab-f6cc-4643-bfc4-3f49de027eea/SpikeT307I-D614G-SIRAH.gro
# Reading 2/3 https://zenodo.org/api/files/e55baaab-f6cc-4643-bfc4-3f49de027eea/SpikeWT-SIRAH.gro
# 478/996
# Reading 0/2 https://zenodo.org/api/files/b670f7c6-57e4-4f22-8da5-01fbeda2ecba/ORADD_closed_state.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '5583119', 'atom_number': 95196, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': True, 'has_glucid': False, 'filename': 'ORADD_closed_state.gro', 'is_AA': True}
# Reading 1/2 https://zenodo.org/api/files/b670f7c6-57e4-4f22-8da5-01fbeda2ecba/ORADD_open_state.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '5583119', 'atom_number': 95175, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': True, 'has_glucid': False, 'filename': 'ORADD_open_state.gro', 'is_AA': True}
# 479/996
# Reading  0/12 https://zenodo.org/api/files/b0e5e6a8-9982-4695-8a34-e33f10850e9c/conf_10000ps.gro
# Reading  1/12 https://zenodo.org/api/files/b0e5e6a8-9982-4695-8a34-e33f10850e9c/conf_1000ps.gro
# Reading  2/12 https://zenodo.org/api/files/b0e5e6a8-9982-4695-8a34-e33f10850e9c/conf_10ps.gro
# Reading  3/12 https://zenodo.org/api/files/b0e5e6a8-9982-4695-8a34-e33f10850e9c/conf_2000ps.gro
# Reading  4/12 https://zenodo.org/api/files/b0e5e6a8-9982-4695-8a34-e33f10850e9c/conf_3000ps.gro
# Reading  5/12 https://zenodo.org/api/files/b0e5e6a8-9982-4695-8a34-e33f10850e9c/conf_4000ps.gro
# Reading  6/12 https://zenodo.org/api/files/b0e5e6a8-9982-4695-8a34-e33f10850e9c/conf_5000ps.gro
# Reading  7/12 https://zenodo.org/api/files/b0e5e6a8-9982-4695-8a34-e33f10850e9c/conf_6000ps.gro
# Reading  8/12 https://zenodo.org/api/files/b0e5e6a8-9982-4695-8a34-e33f10850e9c/conf_7000ps.gro
# Reading  9/12 https://zenodo.org/api/files/b0e5e6a8-9982-4695-8a34-e33f10850e9c/conf_8000ps.gro
# Reading 10/12 https://zenodo.org/api/files/b0e5e6a8-9982-4695-8a34-e33f10850e9c/conf_9000ps.gro
# Reading 11/12 https://zenodo.org/api/files/b0e5e6a8-9982-4695-8a34-e33f10850e9c/conf_ini.gro
# 480/996
# Reading 0/1 https://zenodo.org/api/files/fec66ffe-c8c2-4b9f-b5f8-a1dd40a16ed6/input.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '1307484', 'atom_number': 51519, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': True, 'has_glucid': False, 'filename': 'input.gro', 'is_AA': True}
# 481/996
# Reading 0/1 https://zenodo.org/api/files/ad3936be-874a-4803-b71f-5f95f3a11f02/start.gro
# 482/996
# Reading 0/9 https://zenodo.org/api/files/36bdbc3e-dc3f-44a9-b2bb-e3963c4bac5a/md-production_crystallographic_1.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '825040', 'atom_number': 99208, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': True, 'has_glucid': True, 'filename': 'md-production_crystallographic_1.gro', 'is_AA': True}
# Reading 1/9 https://zenodo.org/api/files/36bdbc3e-dc3f-44a9-b2bb-e3963c4bac5a/md-production_crystallographic_2.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '825040', 'atom_number': 99208, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': True, 'has_glucid': True, 'filename': 'md-production_crystallographic_2.gro', 'is_AA': True}
# Reading 2/9 https://zenodo.org/api/files/36bdbc3e-dc3f-44a9-b2bb-e3963c4bac5a/md-production_crystallographic_3.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '825040', 'atom_number': 99208, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': True, 'has_glucid': True, 'filename': 'md-production_crystallographic_3.gro', 'is_AA': True}
# Reading 3/9 https://zenodo.org/api/files/36bdbc3e-dc3f-44a9-b2bb-e3963c4bac5a/md-production_parallel_1.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '825040', 'atom_number': 99238, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': True, 'has_glucid': True, 'filename': 'md-production_parallel_1.gro', 'is_AA': True}
# Reading 4/9 https://zenodo.org/api/files/36bdbc3e-dc3f-44a9-b2bb-e3963c4bac5a/md-production_parallel_2.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '825040', 'atom_number': 99238, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': True, 'has_glucid': True, 'filename': 'md-production_parallel_2.gro', 'is_AA': True}
# Reading 5/9 https://zenodo.org/api/files/36bdbc3e-dc3f-44a9-b2bb-e3963c4bac5a/md-production_parallel_3.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '825040', 'atom_number': 99238, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': True, 'has_glucid': True, 'filename': 'md-production_parallel_3.gro', 'is_AA': True}
# Reading 6/9 https://zenodo.org/api/files/36bdbc3e-dc3f-44a9-b2bb-e3963c4bac5a/md-production_upright_1.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '825040', 'atom_number': 99244, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': True, 'has_glucid': True, 'filename': 'md-production_upright_1.gro', 'is_AA': True}
# Reading 7/9 https://zenodo.org/api/files/36bdbc3e-dc3f-44a9-b2bb-e3963c4bac5a/md-production_upright_2.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '825040', 'atom_number': 99244, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': True, 'has_glucid': True, 'filename': 'md-production_upright_2.gro', 'is_AA': True}
# Reading 8/9 https://zenodo.org/api/files/36bdbc3e-dc3f-44a9-b2bb-e3963c4bac5a/md-production_upright_3.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '825040', 'atom_number': 99244, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': True, 'has_glucid': True, 'filename': 'md-production_upright_3.gro', 'is_AA': True}
# 483/996
# Reading 0/1 https://zenodo.org/api/files/9b4e6932-6e67-4537-8424-c63f2ce78ade/MD_DOPC-PY0C_NHPR_400-500ns_nove.gro
# 484/996
# Reading 0/1 https://zenodo.org/api/files/fa25b27b-8167-4c26-8424-6604aca96e08/start.gro
# 485/996
# Reading 0/2 https://zenodo.org/api/files/5886ea42-2992-4c27-90a2-cb3411fde9c6/md_fit.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '3476169', 'atom_number': 136334, 'has_protein': True, 'has_nucleic': False, 'has_lipid': True, 'has_water_ion': True, 'has_glucid': False, 'filename': 'md_fit.gro', 'is_AA': True}
# Reading 1/2 https://zenodo.org/api/files/5886ea42-2992-4c27-90a2-cb3411fde9c6/stable_open.pdb
# {'dataset_origin': 'zenodo', 'dataset_id': '3476169', 'atom_number': 27395, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': False, 'has_glucid': False, 'filename': 'stable_open.pdb', 'is_AA': True}
# 486/996
# Reading 0/1 https://zenodo.org/api/files/1b21925d-9306-4d26-9496-851b1570d2bd/starting_frame.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '825116', 'atom_number': 131662, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': True, 'has_glucid': True, 'filename': 'starting_frame.gro', 'is_AA': True}
# 487/996
# Reading 0/5 https://zenodo.org/api/files/61121d2d-6188-4574-8bbf-8b7a234db020/trackIII_topology.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '3885771', 'atom_number': 3159, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': False, 'has_glucid': False, 'filename': 'trackIII_topology.gro', 'is_AA': True}
# Reading 1/5 https://zenodo.org/api/files/61121d2d-6188-4574-8bbf-8b7a234db020/trackII_topology.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '3885771', 'atom_number': 3159, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': False, 'has_glucid': False, 'filename': 'trackII_topology.gro', 'is_AA': True}
# Reading 2/5 https://zenodo.org/api/files/61121d2d-6188-4574-8bbf-8b7a234db020/trackI_topology.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '3885771', 'atom_number': 3159, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': False, 'has_glucid': False, 'filename': 'trackI_topology.gro', 'is_AA': True}
# Reading 3/5 https://zenodo.org/api/files/61121d2d-6188-4574-8bbf-8b7a234db020/trackIV_topology.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '3885771', 'atom_number': 3159, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': False, 'has_glucid': False, 'filename': 'trackIV_topology.gro', 'is_AA': True}
# Reading 4/5 https://zenodo.org/api/files/61121d2d-6188-4574-8bbf-8b7a234db020/trackV_topology.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '3885771', 'atom_number': 3159, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': False, 'has_glucid': False, 'filename': 'trackV_topology.gro', 'is_AA': True}
# 488/996
# Reading 0/3 https://zenodo.org/api/files/879391f1-b7f3-4874-85d2-9cfada4f7f2c/C11.pdb
# Reading 1/3 https://zenodo.org/api/files/879391f1-b7f3-4874-85d2-9cfada4f7f2c/C25.pdb
# Reading 2/3 https://zenodo.org/api/files/879391f1-b7f3-4874-85d2-9cfada4f7f2c/non-water-start.gro
# 489/996
# Reading 0/1 https://zenodo.org/api/files/c26a4318-48fc-4c2f-84ab-7d04b92f7509/input.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '1307182', 'atom_number': 36466, 'has_protein': True, 'has_nucleic': True, 'has_lipid': False, 'has_water_ion': True, 'has_glucid': False, 'filename': 'input.gro', 'is_AA': True}
# 490/996
# Reading 0/1 https://zenodo.org/api/files/cb1e23d7-ffe6-4b2f-9e66-b8c90d9835f4/md.gro
# 491/996
# Reading 0/1 https://zenodo.org/api/files/421ece74-f1cd-478b-950f-48074fa4e8fc/system.gro
# {'dataset_origin': 'zenodo', 'dataset_id': '2644158', 'atom_number': 184994, 'has_protein': True, 'has_nucleic': False, 'has_lipid': False, 'has_water_ion': True, 'has_glucid': False, 'filename': 'system.gro', 'is_AA': True}
# 492/996
# Reading 0/1 https://zenodo.org/api/files/6419aaab-d9c2-484a-ba9c-80022b92f6fe/start.gro
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-25ec6ac6e687> in <module>
#      22                 rdr = get_coord_info(infile, source,
#      23                                gro_file_name=f'{row["dataset_origin"]}|{row["dataset_id"]}|{infile.split("/")[-1]}',
# ---> 24                                gro_file_idx=index, GRO_FILE_NUMBER=len(coordinate_files))
#      25                 if rdr['is_AA']==True:
#      26                     print(rdr)
#
# <ipython-input-8-a3a7dcfba5c1> in get_coord_info(coord_file, source, gro_file_name, gro_file_idx, GRO_FILE_NUMBER)
#      10                 NUCLEIC_RESIDUES,
#      11                 WATER_ION_RESIDUES,
# ---> 12                 GLUCID_RESIDUES
#      13             )
#      14     elif source=='pdb':
#
# <ipython-input-6-4dc9876b96bb> in extract_remote_info_from_gro(gro_file_path, target_path, gro_file_counter, gro_file_number, protein_residues, lipid_residues, nucleic_residues, water_ion_residues, glucid_residues)
#      81         f"Reading {gro_file_counter:{len(str(gro_file_number))}d}/{gro_file_number} {str(gro_file_path)}"
#      82     )
# ---> 83     f = requests.get(gro_file_path)
#      84     prev_residue_number = -999
#      85     all_gro = []
#
# ~/dev/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/dev/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/dev/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/dev/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     695
#     696         if not stream:
# --> 697             r.content
#     698
#     699         return r
#
# ~/dev/anaconda3/lib/python3.7/site-packages/requests/models.py in content(self)
#     829                 self._content = None
#     830             else:
# --> 831                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     832
#     833         self._content_consumed = True
#
# ~/dev/anaconda3/lib/python3.7/site-packages/requests/models.py in generate()
#     751             if hasattr(self.raw, 'stream'):
#     752                 try:
# --> 753                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     754                         yield chunk
#     755                 except ProtocolError as e:
#
# ~/dev/anaconda3/lib/python3.7/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     574         else:
#     575             while not is_fp_closed(self._fp):
# --> 576                 data = self.read(amt=amt, decode_content=decode_content)
#     577
#     578                 if data:
#
# ~/dev/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# ~/dev/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~/dev/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     499         # connection, and the user is reading more bytes than will be provided
#     500         # (for example, reading in 1k chunks)
# --> 501         n = self.fp.readinto(b)
#     502         if not n and b:
#     503             # Ideally, we would raise IncompleteRead if the content-length
#
# ~/dev/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/dev/anaconda3/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# ~/dev/anaconda3/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
infos = pd.read_csv(os.path.join(os.getcwd(), '../data', 'dataset_info.tsv'), sep="\t")
print(len(infos['dataset_id_ori'].unique()), len(infos))
infos

# %% [markdown]
# ## get AA + protein

# %%
infos = pd.read_csv(os.path.join(os.getcwd(), '../data', 'dataset_info.tsv'), sep="\t")
print(len(infos['dataset_id_ori'].unique()), len(infos))
infos
# Out:
# 482 4108
#       dataset_id_ori    category                  file_name file_type  \
# 0     zenodo_3965660  coordinate        coexistence_PSM.gro       gro
# 1     zenodo_3965660  trajectory        coexistence_PSM.xtc       xtc
# 2     zenodo_4115152  coordinate          bar_curved_r1.gro       gro
# 3     zenodo_4115152  coordinate          bar_curved_r2.gro       gro
# 4     zenodo_4115152  trajectory  bar_curved_r1_nowater.xtc       xtc
# ...              ...         ...                        ...       ...
# 4103  zenodo_6456372  coordinate                  PB-01.pdb       pdb
# 4104  zenodo_6456372  coordinate                  PB-02.pdb       pdb
# 4105  zenodo_6456372  coordinate                  PB-03.pdb       pdb
# 4106  zenodo_6456372  coordinate                  PB-04.pdb       pdb
# 4107  zenodo_3727549  coordinate                   traj.pdb       pdb
#
#               size                                                url  \
# 0     7.975367e+06  https://zenodo.org/api/files/37920b54-82ad-436...
# 1     4.292043e+10  https://zenodo.org/api/files/37920b54-82ad-436...
# 2     1.546060e+07  https://zenodo.org/api/files/cc5d7019-f47e-40d...
# 3     1.546060e+07  https://zenodo.org/api/files/cc5d7019-f47e-40d...
# 4     1.998482e+10  https://zenodo.org/api/files/cc5d7019-f47e-40d...
# ...            ...                                                ...
# 4103  4.005454e+06  https://zenodo.org/api/files/5d900911-5e28-4d1...
# 4104  4.005454e+06  https://zenodo.org/api/files/5d900911-5e28-4d1...
# 4105  4.005454e+06  https://zenodo.org/api/files/5d900911-5e28-4d1...
# 4106  4.005454e+06  https://zenodo.org/api/files/5d900911-5e28-4d1...
# 4107  1.325222e+06  https://zenodo.org/api/files/ddcd24e9-c7ec-4cd...
#
#      atom_num has_protein has_nucleic has_lipid has_water_ion has_glucid  \
# 0      115584       False       False      True          True      False
# 1        None        None        None      None          None       None
# 2      224066        True       False      True          True      False
# 3      224066        True       False      True          True      False
# 4        None        None        None      None          None       None
# ...       ...         ...         ...       ...           ...        ...
# 4103    50701        True       False      True          True      False
# 4104    50701        True       False      True          True      False
# 4105    50701        True       False      True          True      False
# 4106    50701        True       False      True          True      False
# 4107    17208       False       False      True          True      False
#
#       is_AA
# 0     False
# 1      None
# 2     False
# 3     False
# 4      None
# ...     ...
# 4103   True
# 4104   True
# 4105   True
# 4106   True
# 4107  False
#
# [4108 rows x 13 columns]

# %%
infos_ids = infos.copy()
fitting_ids = infos_ids.loc[((infos_ids['is_AA']=='True') & (infos_ids['has_protein']=='True'))]['dataset_id_ori'].unique()
print(len(fitting_ids))
fitting_df = infos_ids.loc[infos_ids['dataset_id_ori'].isin(fitting_ids)]
not_fitting_ids = fitting_df.loc[((fitting_df['is_AA']=='False'))]['dataset_id_ori'].unique()
fitting_df = fitting_df.loc[~fitting_df['dataset_id_ori'].isin(not_fitting_ids)]
fitting_df.sort_values(by=['size'], ascending=False, inplace=True)
fitting_df.atom_num.replace(to_replace=[None, 'None'], value=None, inplace=True)
fitting_df['atom_num'] = fitting_df['atom_num'].apply(lambda x: None if x in [None, 'None'] else int(x))
print('trajectory:\n', fitting_df.loc[fitting_df['category']=='trajectory'].describe())
print('coordinate:\n', fitting_df.loc[fitting_df['category']=='coordinate'].describe())
# Out:
# 94
# trajectory:
#                 size      atom_num
# count  5.090000e+02  6.300000e+01
# mean   2.324818e+09  7.894806e+05
# std    5.176207e+09  2.521899e+05
# min    5.619520e+05  8.307000e+03
# 25%    8.910778e+07  4.980730e+05
# 50%    3.880190e+08  9.364600e+05
# 75%    1.926148e+09  9.364600e+05
# max    3.763558e+10  1.052627e+06
# coordinate:
#                 size      atom_num
# count  4.220000e+02  4.220000e+02
# mean   6.388385e+06  1.083017e+05
# std    7.480993e+06  1.144924e+05
# min    4.973700e+04  6.270000e+02
# 25%    4.005454e+06  5.070100e+04
# 50%    4.847897e+06  1.033750e+05
# 75%    7.132967e+06  1.077290e+05
# max    7.398050e+07  1.055753e+06

# %%
fitting_df.sort_values(by=['dataset_id_ori', 'file_name'], ascending=True, inplace=True)
fitting_df = fitting_df.reset_index(drop=True)
fitting_df.to_csv(os.path.join(os.getcwd(), '../data', 'AA_prot_info.tsv'), sep="\t")
fitting_df
# Out:
#      dataset_id_ori    category            file_name file_type          size  \
# 0    zenodo_1010142  coordinate              run.gro       gro  1.915140e+06
# 1    zenodo_1010142  trajectory           run1-2.xtc       xtc  7.990016e+09
# 2    zenodo_1010232  coordinate            begin.gro       gro  1.249067e+06
# 3    zenodo_1010232  coordinate             conf.gro       gro  6.538700e+04
# 4    zenodo_1010232  coordinate          run70ns.gro       gro  1.915178e+06
# ..              ...         ...                  ...       ...           ...
# 926   zenodo_825389  trajectory  md-production_7.xtc       xtc  1.808458e+09
# 927   zenodo_825389  coordinate  md-production_8.gro       gro  4.466611e+06
# 928   zenodo_825389  trajectory  md-production_8.xtc       xtc  1.808572e+09
# 929   zenodo_825389  coordinate  md-production_9.gro       gro  4.466611e+06
# 930   zenodo_825389  trajectory  md-production_9.xtc       xtc  1.804870e+09
#
#                                                    url  atom_num has_protein  \
# 0    https://zenodo.org/api/files/f3ad9975-a342-41a...   27755.0        True
# 1    https://zenodo.org/api/files/f3ad9975-a342-41a...       NaN        None
# 2    https://zenodo.org/api/files/34892030-83ff-4b9...   27755.0        True
# 3    https://zenodo.org/api/files/34892030-83ff-4b9...    1451.0        True
# 4    https://zenodo.org/api/files/34892030-83ff-4b9...   27755.0        True
# ..                                                 ...       ...         ...
# 926  https://zenodo.org/api/files/c9968144-fa39-45f...       NaN        None
# 927  https://zenodo.org/api/files/c9968144-fa39-45f...   99256.0        True
# 928  https://zenodo.org/api/files/c9968144-fa39-45f...       NaN        None
# 929  https://zenodo.org/api/files/c9968144-fa39-45f...   99256.0        True
# 930  https://zenodo.org/api/files/c9968144-fa39-45f...       NaN        None
#
#     has_nucleic has_lipid has_water_ion has_glucid is_AA
# 0         False     False          True      False  True
# 1          None      None          None       None  None
# 2         False     False          True      False  True
# 3         False     False         False      False  True
# 4         False     False          True      False  True
# ..          ...       ...           ...        ...   ...
# 926        None      None          None       None  None
# 927       False     False          True       True  True
# 928        None      None          None       None  None
# 929       False     False          True       True  True
# 930        None      None          None       None  None
#
# [931 rows x 13 columns]

# %% [markdown]
# ## get zip files

# %%
traj_df_from_zip = all_df.copy()
traj_df_from_zip = traj_df_from_zip.loc[(traj_df_from_zip['from_zip_file']==True) | (traj_df_from_zip['file_type']=='zip')].reset_index(drop=True)
traj_df_from_zip_not = traj_df_from_zip.loc[(traj_df_from_zip['file_name'].str.contains("CG"))]['dataset_id_ori'].unique()

traj_df_from_zip = traj_df_from_zip.loc[~traj_df_from_zip['dataset_id_ori'].isin(traj_df_from_zip_not)]
traj_df_from_zip
traj_df_from_zip_traj = traj_df_from_zip.loc[traj_df_from_zip['file_type'].isin(['xtc', 'trr', 'dcd'])]['dataset_id_ori'].unique()
traj_df_from_zip = traj_df_from_zip.loc[traj_df_from_zip['dataset_id_ori'].isin(traj_df_from_zip_traj)]
print(len(traj_df_from_zip['dataset_id_ori'].unique()))
print(traj_df_from_zip.columns)
traj_df_from_zip = traj_df_from_zip[['dataset_id_ori', 'category', 'file_name', 'file_type', 
                                     'file_size', 'file_url', 'dataset_url', 'from_zip_file', 'origin_zip_file']].reset_index(drop=True)
traj_df_from_zip.sort_values(by=['dataset_id_ori', 'file_name'], ascending=True, inplace=True)
traj_df_from_zip.to_csv(os.path.join(os.getcwd(), '../data', 'zip_info.tsv'), sep="\t")
traj_df_from_zip = traj_df_from_zip.loc[traj_df_from_zip['from_zip_file']==False].reset_index(drop=True)
traj_df_from_zip.to_csv(os.path.join(os.getcwd(), '../data', 'zip_unfold_info.tsv'), sep="\t")

traj_df_from_zip
# Out:
# 115
# Index(['dataset_origin', 'dataset_id', 'doi', 'date_creation',
#        'date_last_modified', 'date_fetched', 'file_number', 'download_number',
#        'view_number', 'license', 'dataset_url', 'year', 'file_type',
#        'file_size', 'file_md5', 'from_zip_file', 'file_name', 'file_url',
#        'origin_zip_file', 'category', 'engine_MD', 'dataset_id_ori'],
#       dtype='object')
#         dataset_id_ori category                 file_name file_type  \
# 0    figshare_11764158     none               QHD_LP1.zip       zip
# 1    figshare_11764158     none               QHD_LP2.zip       zip
# 2    figshare_11764158     none               QHD_LP3.zip       zip
# 3    figshare_11764158     none               QHD_LP4.zip       zip
# 4    figshare_11764158     none               QHD_LP5.zip       zip
# ..                 ...      ...                       ...       ...
# 374     zenodo_6426152     none  PeptideGraphZenodoV2.zip       zip
# 375     zenodo_6445362     none    molecular-dynamics.zip       zip
# 376     zenodo_6445362     none               scripts.zip       zip
# 377     zenodo_6445485     none    molecular-dynamics.zip       zip
# 378     zenodo_6445485     none               scripts.zip       zip
#
#         file_size                                           file_url  \
# 0    1.112512e+09    https://ndownloader.figshare.com/files/21448860
# 1    1.112907e+09    https://ndownloader.figshare.com/files/21448803
# 2    1.112511e+09    https://ndownloader.figshare.com/files/21448776
# 3    1.112508e+09    https://ndownloader.figshare.com/files/21448701
# 4    1.112129e+09    https://ndownloader.figshare.com/files/21448647
# ..            ...                                                ...
# 374  8.388713e+09  https://zenodo.org/api/files/8588ea90-cacf-4dc...
# 375  1.032550e+09  https://zenodo.org/api/files/9f47c8ff-0428-45a...
# 376  1.605454e+06  https://zenodo.org/api/files/9f47c8ff-0428-45a...
# 377  9.713144e+08  https://zenodo.org/api/files/7882ea28-bef7-47d...
# 378  1.568151e+06  https://zenodo.org/api/files/7882ea28-bef7-47d...
#
#                                        dataset_url  from_zip_file  \
# 0    https://api.figshare.com/v2/articles/11764158          False
# 1    https://api.figshare.com/v2/articles/11764158          False
# 2    https://api.figshare.com/v2/articles/11764158          False
# 3    https://api.figshare.com/v2/articles/11764158          False
# 4    https://api.figshare.com/v2/articles/11764158          False
# ..                                             ...            ...
# 374              https://zenodo.org/record/6426152          False
# 375              https://zenodo.org/record/6445362          False
# 376              https://zenodo.org/record/6445362          False
# 377              https://zenodo.org/record/6445485          False
# 378              https://zenodo.org/record/6445485          False
#
#     origin_zip_file
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
# ..              ...
# 374            none
# 375            none
# 376            none
# 377            none
# 378            none
#
# [379 rows x 9 columns]
